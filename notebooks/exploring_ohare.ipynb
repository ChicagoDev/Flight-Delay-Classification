# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

# %%
ord_flights = pd.read_csv('../data/ohare/01_2018_ORD_AIR_TFFX.csv', low_memory=False)

# %%
ord_flights.columns.tolist()
# Out:
# ['Year',
#  'Quarter',
#  'Month',
#  'DayofMonth',
#  'DayOfWeek',
#  'FlightDate',
#  'Reporting_Airline',
#  'DOT_ID_Reporting_Airline',
#  'IATA_CODE_Reporting_Airline',
#  'Tail_Number',
#  'Flight_Number_Reporting_Airline',
#  'OriginAirportID',
#  'OriginAirportSeqID',
#  'OriginCityMarketID',
#  'Origin',
#  'OriginCityName',
#  'OriginState',
#  'OriginStateFips',
#  'OriginStateName',
#  'OriginWac',
#  'DestAirportID',
#  'DestAirportSeqID',
#  'DestCityMarketID',
#  'Dest',
#  'DestCityName',
#  'DestState',
#  'DestStateFips',
#  'DestStateName',
#  'DestWac',
#  'CRSDepTime',
#  'DepTime',
#  'DepDelay',
#  'DepDelayMinutes',
#  'DepDel15',
#  'DepartureDelayGroups',
#  'DepTimeBlk',
#  'TaxiOut',
#  'WheelsOff',
#  'WheelsOn',
#  'TaxiIn',
#  'CRSArrTime',
#  'ArrTime',
#  'ArrDelay',
#  'ArrDelayMinutes',
#  'ArrDel15',
#  'ArrivalDelayGroups',
#  'ArrTimeBlk',
#  'Cancelled',
#  'CancellationCode',
#  'Diverted',
#  'CRSElapsedTime',
#  'ActualElapsedTime',
# ...

# %%
mask_from_ord = ord_flights.Origin == 'ORD'

mask_to_ord = ord_flights.Origin != 'ORD'

flights_from_ohare = ord_flights[mask_from_ord]
flights_to_ohare = ord_flights[mask_to_ord]

# %% [markdown]
# ### The baseline Flight delay

# %%
flights_from_ohare.DepDelayMinutes.mean()
# Out:
# 16.09576119402985

# %%
flights_to_ohare.DepDelayMinutes.mean()
# Out:
# 15.586940980220827

# %%
flights_from_ohare.TaxiOut.max()
# Out:
# 118.0

# %%
flights_to_ohare.TaxiOut.max()
# Out:
# 158.0

# %%
regions = { 'SE': ['ATL','DFW'],
            'SW': ['LAX', 'LAS'],
            'NW': ['SFO', 'DEN'], 
            'NE': ['JFK','EWR']
          }

# %%
m_tst = (flights_from_ohare.Dest == regions['SE'][0]) || (flights_from_ohare.Dest == regions['SE'][1])
# Out:
#   File "<ipython-input-44-ccb796f56cc0>", line 1
#     m_tst = (flights_from_ohare.Dest == regions['SE'][0]) || (flights_from_ohare.Dest == regions['SE'][1])
#                                                            ^
# SyntaxError: invalid syntax

# %%
flights_from_ohare[(flights_from_ohare.Dest == regions['SE'][0]) | (flights_from_ohare.Dest == regions['SE'][1])]
# Out:
#        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 106    2018        1      1          26          5  2018-01-26
# 161    2018        1      1          26          5  2018-01-26
# 175    2018        1      1          26          5  2018-01-26
# 199    2018        1      1          26          5  2018-01-26
# 211    2018        1      1          26          5  2018-01-26
# 215    2018        1      1          26          5  2018-01-26
# 320    2018        1      1          26          5  2018-01-26
# 379    2018        1      1          26          5  2018-01-26
# 449    2018        1      1          25          4  2018-01-25
# 516    2018        1      1          25          4  2018-01-25
# 539    2018        1      1          25          4  2018-01-25
# 552    2018        1      1          25          4  2018-01-25
# 556    2018        1      1          25          4  2018-01-25
# 662    2018        1      1          25          4  2018-01-25
# ...

# %%
def get_ports(port, column_name, df):
    mask = (df[column_name] == port)
    return df[mask]

# %%
def get_ports(region_arr, column_name, df):
    mask = ((df[column_name] == region_arr[0]) | (df[column_name] == region_arr[1]))
    return df[mask]

# %%
get_ports('ATL', 'Origin', flights_to_ohare)
# Out:
#        Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 11     2018        1      1          27          6  2018-01-27
# 209    2018        1      1          26          5  2018-01-26
# 348    2018        1      1          26          5  2018-01-26
# 363    2018        1      1          26          5  2018-01-26
# 550    2018        1      1          25          4  2018-01-25
# 689    2018        1      1          25          4  2018-01-25
# 704    2018        1      1          25          4  2018-01-25
# 887    2018        1      1          24          3  2018-01-24
# 1030   2018        1      1          24          3  2018-01-24
# 1222   2018        1      1          23          2  2018-01-23
# 1358   2018        1      1          23          2  2018-01-23
# 1374   2018        1      1          23          2  2018-01-23
# 1555   2018        1      1           8          1  2018-01-08
# 1760   2018        1      1           7          7  2018-01-07
# ...

# %%
from collections import defaultdict

ohare_outb_delays = defaultdict(float)


for reg, airports in regions.items():
    
    for port in airports:
        ohare_outb_delays[port] = get_ports(port, 'Origin', flights_to_ohare).DepDelayMinutes.mean()

# %%
ohare_outb_delays
# Out:
# defaultdict(float,
#             {'ATL': 12.029173419773096,
#              'DFW': 8.72892561983471,
#              'LAX': 6.320783132530121,
#              'LAS': 6.072972972972973,
#              'SFO': 10.21369294605809,
#              'DEN': 6.767634854771784,
#              'JFK': 16.844919786096256,
#              'EWR': 11.223809523809523})

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import defaultdict

class OrdUtils(object):
	
	regions = {'SE': ['ATL', 'DFW'],
	           'SW': ['LAX', 'LAS'],
	           'NW': ['SFO', 'DEN'],
	           'NE': ['JFK', 'EWR']
	           }
	
	def __init__(self):
		
		ord_flights = pd.read_csv('../data/ohare/01_2018_ORD_AIR_TFFX.csv', low_memory=False)
		
		#Split the data between inbound and outbound flights
		mask_from_ord = ord_flights.Origin == 'ORD'
		mask_to_ord = ord_flights.Origin != 'ORD'
		self.flights_from_ohare = ord_flights[mask_from_ord]
		self.flights_to_ohare = ord_flights[mask_to_ord]
	
	def get_baselines(self):
		ob_del = self.flights_from_ohare.DepDelayMinutes.mean()
		ib_del = self.flights_to_ohare.DepDelayMinutes.mean()
		
		ob_taxi_del = self.flights_from_ohare.TaxiOut.max()
		ib_taxi_del = self.flights_to_ohare.TaxiOut.max()
		
		return {
			'ob_del': ob_del, 'ib_del': ib_del,
			'ob_taxi_tm': ob_taxi_del, 'ib_taxi_tm': ib_taxi_del
		}
	
	def get_ports(self, port, column_name, df):
		"""Filters a DF on a given airport. Convenience Method"""
		mask = (df[column_name] == port)
		return df[mask]
	
	def get_ib_delays(self):
		ohare_ib_delays = defaultdict(float)
		
		for reg, airports in self.regions.items():
			
			for port in airports:
				ohare_ib_delays[port] = self.get_ports(port, 'Origin', self.flights_to_ohare).DepDelayMinutes.mean()
				
		return ohare_ib_delays
		
	def get_ob_delays(self):
		
		ohare_outb_delays = defaultdict(float)
	
		for reg, airports in self.regions.items():
		
			for port in airports:
				ohare_outb_delays[port] = self.get_ports(port, 'Dest', self.flights_from_ohare).DepDelayMinutes.mean()
				
		return ohare_outb_delays

# %%
faa = OrdUtils()

faa.get_ob_delays()

faa.get_ib_delays()

faa.get_baselines()
