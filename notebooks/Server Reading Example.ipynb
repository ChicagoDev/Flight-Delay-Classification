# %%
import pickle
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/bjg/Metis/Projects/McNulty/FlightOnTime/notebooks'

# %%
data = None

# %%
with open('../data/server_runs/run_2_dict.pkl', 'rb') as fl:
    data = pickle.load(fl)
fl.close()

# %%
data['airline_delays']
# Out:
#                    Total_Departures  Late_Departures  Avg_Delay  \
# Reporting_Airline
# 9E                             1670              560  59.892857
# AA                           117170            46600  34.167167
# AS                             4700             1473  33.823489
# B6                             4575             2349  55.302682
# DL                            15567             5778  43.234337
# EV                            31220             8494  47.783494
# F9                             5392             1918  62.122002
# MQ                            49497            13363  34.783058
# NK                            17985             5701  48.439572
# OH                             1881              706  47.283286
# OO                           140053            45425  52.795003
# UA                           137855            45569  42.743203
# VX                             1706              643  39.925350
# ...

# %%
data['city_ob_delays']
# Out:
#          ATL        DFW        LAX        LAS        SFO        DEN  \
# 0  14.593725  16.226525  14.865972  14.295452  18.932056  13.557221
#
#          JFK        EWR    ORD_AVG
# 0  29.900742  21.302675  14.796784

# %%
data['day_of_week_delays']
# Out:
#            Day  Flights  DepDel15
# DayOfWeek
# 1          MON    81206   18592.0
# 2          TUE    79772   15019.0
# 3          WED    80116   14878.0
# 4          THU    80494   16229.0
# 5          FRI    80783   17063.0
# 6          SAT    64412   11210.0
# 7          SUN    77629   14809.0
