# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from FAA import Ohare
from FAA import Hanger
import pandas as pd
from sqlalchemy import create_engine

# %%
username = 'bjg' # or 'ubuntu'
database_name = 'faa'

params = { 'host': 'localhost',
           'port': 5432
}

connection_string = f'postgres://{username}:{params["host"]}@{params["host"]}:{params["port"]}/{database_name}'

engine = create_engine(connection_string)

# %%
pd.read_sql_table('JETFUEL_PRICE', connection_string)
# Out:
#           DATE  WJFUELUSGULF
# 0   2017-01-06         1.539
# 1   2017-01-13         1.506
# 2   2017-01-20         1.505
# 3   2017-01-27         1.513
# 4   2017-02-03         1.518
# 5   2017-02-10         1.529
# 6   2017-02-17         1.552
# 7   2017-02-24         1.566
# 8   2017-03-03         1.527
# 9   2017-03-10         1.485
# 10  2017-03-17         1.401
# 11  2017-03-24         1.409
# 12  2017-03-31         1.450
# 13  2017-04-07         1.512
# 14  2017-04-14         1.568
# 15  2017-04-21         1.511
# 16  2017-04-28         1.448
# 17  2017-05-05         1.364
# 18  2017-05-12         1.369
# 19  2017-05-19         1.426
# 20  2017-05-26         1.478
# 21  2017-06-02         1.404
# 22  2017-06-09         1.302
# 23  2017-06-16         1.290
# 24  2017-06-23         1.255
# 25  2017-06-30         1.307
# 26  2017-07-07         1.352
# 27  2017-07-14         1.361
# 28  2017-07-21         1.425
# 29  2017-07-28         1.497
# ..         ...           ...
# ...

# %%
faa = Ohare.Ohare(sql=True)
Hanger.Hanger.get_airline_departures(faa.flights_from_ohare)


## Read the database into a dataframe. 
## Call the static Hanger method.

# %%
type(Hanger.Hanger.get_airline_departures(faa.flights_from_ohare))
# Out:
# str

# %%
pd.read_json(Hanger.Hanger.get_airline_departures(faa.flights_from_ohare))
# Out:
#     Total_Departures  Late_Departures  Avg_Delay  Early_Departures  \
# 9E              1670              560  59.892857               999
# AA            117170            46600  34.167167             68912
# AS              4700             1473  33.823489              3202
# B6              4575             2349  55.302682              2102
# DL             15567             5778  43.234337              9713
# EV             31220             8494  47.783494             22140
# F9              5392             1918  62.122002              3412
# MQ             49497            13363  34.783058             34537
# NK             17985             5701  48.439572             11883
# OH              1881              706  47.283286              1072
# OO            140053            45425  52.795003             91632
# UA            137855            45569  42.743203             91306
# VX              1706              643  39.925350              1059
# ...

# %%
os.getcwd()
# Out:
# '/Users/bjg/Metis/Projects/McNulty/FlightOnTime/notebooks'

# %%
df = pd.read_json(Hanger.Hanger.get_airline_departures(faa.flights_from_ohare))

# %%
df.to_json('test.json')
